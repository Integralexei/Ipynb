# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# 27.04.2021
#
# задача 1.7

# %%
df = pd.read_csv(r'C:\Users\Laba\Documents\iris.csv', index_col=0)

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.kdeplot(data=df)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.violinplot(y=df["petal length"])
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
sns.pairplot(df,  hue="species")

# %%
sns.pairplot(df)

# %% [markdown]
# Практические задания Pandas 1.8

# %%
df = pd.DataFrame({'type': ['A', 'A', 'B', 'B'], 'value': [10, 14, 12, 23]})
df
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
df = pd.read_csv(r'C:\Users\Laba\Documents\my_stat.csv')
df.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
subset_1 = df.iloc[:10, [0,2]]
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
df.drop([1, 2, 3], axis=0)

# %%
subset_2 = df.iloc[:,[1, 3]].drop([0, 4])
# subset_2 = subset_2.drop([0, 4], axis=0)
subset_2
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %%
subset_1 = df[(df.V1 > 0) & 
              (df.V3 == 'A')]
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
subset_2 = df[(df.V2 != 10) | 
              (df.V4 >= 1)]
subset_2
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
tu = pd.DataFrame()
tu = subset_2
tu
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
df['V5'] = df['V1'] + df['V4']
df

# %%
df['V6'] = np.log(df['V2'])
df
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# ..   ..   ... ..  ...  ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442
# 497  -1  11.0  B  2.0  1.0  2.397895
# 498   1  11.0  A  2.0  3.0  2.397895
# 499   0   8.0  B  1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
df = pd.read_csv(r'C:\Users\Laba\Documents\my_stat_1.csv')

# %%
df = df.rename(columns={"V1": "session_value", "V2": "group", "V3": "time", "V4": "n_users"})

# %%
df.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9

# %%
df.session_value.fillna(0, inplace=True)
df.session_value = 0
median_df = df.n_users[df.n_users >= 0].median()
median_df
# Out:
# 5.0

# %%
df.head()
# Out:
#    session_value  time group  n_users
# 0              0    12     B        9
# 1              0    11     A       -1
# 2              0     8     A        1
# 3              0     9     B        3
# 4              0    10     B        9

# %%
df.loc[df.n_users < 0, 'n_users'] = median_df

# %%
df.head()
# Out:
#    session_value  time group  n_users
# 0              0    12     B        9
# 1              0    11     A        5
# 2              0     8     A        1
# 3              0     9     B        3
# 4              0    10     B        9

# %%
my_stat = df
my_stat.head()
# Out:
#    session_value  time group  n_users
# 0              0    12     B        9
# 1              0    11     A        5
# 2              0     8     A        1
# 3              0     9     B        3
# 4              0    10     B        9

# %%
my_stat = my_stat.groupby('group' , as_index=False).mean()
my_stat.head()
# Out:
#   group  session_value  time  n_users
# 0     A            0.0   9.0      4.6
# 1     B            0.0  10.0      6.2

# %%
my_stat = my_stat.rename(columns={'session_value':'mean_session_value'})
my_stat.head()
# Out:
#   group  mean_session_value  time  n_users
# 0     A                 0.0   9.0      4.6
# 1     B                 0.0  10.0      6.2

# %%
mean_session_value_data = my_stat.iloc[:,:2]
mean_session_value_data.head()
# Out:
#   group  mean_session_value
# 0     A                 0.0
# 1     B                 0.0
